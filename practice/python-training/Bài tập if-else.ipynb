# %% [markdown]
# ## Bài 1: Nhập vào một số nguyên x kiếm tra số đó là chẵn hay lẻ

# %% [markdown]
# ## Bài 2: Nhập vào một số thực y kiểm tra xem số đó dương âm hay bằng 0

# %% [markdown]
# ## Bài 3: Nhập vào tuổi của một người. Cho biết người đó là trẻ con, người lớn hay người già
# - Trẻ con: nhỏ hơn 18 tuổi
# - Người lớn từ 18 đến 65 tuổi
# - Người già trên 65 tuổi

# %% [markdown]
# ## Bài 4: Nhập vào một năm. Kiểm tra xem năm đó có phải năm nhuận hay không ?

# %% [markdown]
# ## Bài 5: Cho số pi = 3.14, nhập vào bán kính r. Tính chu vi và diện tích hình tròn (làm tròn đến 2 chữ số thập phân)

# %% [markdown]
# ## Bài 6: Nhập vào tên của một người. Kiểm tra tên nhập vào có hợp lệ hay không ?

# %% [markdown]
# ## Bài 7: Nhập vào một số kiểm tra số đó là số thực hay số nguyên

# %% [markdown]
# ## Bài 8: Nhập vào số nguyên dương n kiểm tra số đó có chia hết cho 3 và 5 hay không ?

# %% [markdown]
# ## Bài 9: ![image.png](attachment:image.png)

# %% [markdown]
# <h2>Bài 10: Viết chương trình giải phương trình bậc nhất và bậc hai một ẩn (ax + b = 0 và ax<sup>2</sup> + bx + c = 0)</h2>
