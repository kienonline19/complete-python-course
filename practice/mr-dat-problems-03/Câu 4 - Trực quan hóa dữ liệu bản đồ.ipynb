# %% [markdown]
# ## Cho dữ liệu US_Unemployment_Oct2012.csv và us-states.json, thực hiện các yêu cầu sau:

# %% [markdown]
# 1. Đọc dữ liệu US_Unemployment_Oct2012.csv, hiển thị thông tin chung của dữ liệu bao gồm : head, tail, info, describe

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('US_Unemployment_Oct2012.csv')

# %%
df.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
df.tail()
# Out:
#    State  Unemployment
# 45    VA           5.8
# 46    WA           7.8
# 47    WV           7.5
# 48    WI           6.8
# 49    WY           5.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         50 non-null     object
#  1   Unemployment  50 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 928.0+ bytes

# %%
df.describe()
# Out:
#        Unemployment
# count     50.000000
# mean       7.146000
# std        1.665154
# min        3.200000
# 25%        5.800000
# 50%        7.100000
# 75%        8.400000
# max       10.300000

# %% [markdown]
# 2. Tạo bản đồ thế giới có kiểu cartodbpositron với location([48, -102]) và zoom level (zoom_start=3) gợi ý như hình sau:

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in d:\complete-python-course\.venv\lib\site-packages (0.12.1.post1)
# Requirement already satisfied: jinja2>=2.9 in d:\complete-python-course\.venv\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.3.0 in d:\complete-python-course\.venv\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: requests in d:\complete-python-course\.venv\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in d:\complete-python-course\.venv\lib\site-packages (from folium) (1.23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\complete-python-course\.venv\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\complete-python-course\.venv\lib\site-packages (from requests->folium) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\complete-python-course\.venv\lib\site-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\complete-python-course\.venv\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\complete-python-course\.venv\lib\site-packages (from requests->folium) (3.3)

# %%
import folium
from folium.plugins import MarkerCluster

# %%
world_map = folium.Map(location=[48,-102], zoom_start=3, tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)

# %%
for i in range(len(df)):
    lat = 48
    long = -102
    radius=5
    popup_text = """State : {}<br>
                # %of Unemployment: {}<br>"""
    popup_text = popup_text.format(df.iloc[i]['State'],
                               df.iloc[i]['Unemployment']
                               )
    folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill=True).add_to(marker_cluster)
    
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_337a12422fceb13a7748c3bcf7478ba0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_337a12422fceb13a7748c3bcf7478ba0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_337a12422fceb13a7748c3bcf7478ba0 = L.map(
#                 &quot;map_337a12422fceb13a7748c3bcf7478ba0&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a5c5fbc2ef0ced904f3bfa266aa3e01 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_337a12422fceb13a7748c3bcf7478ba0);
#
#
#             var marker_cluster_49b04ca0bca57d9a6e131596b8379b87 = L.markerClusterGroup(
#                 {}
#             );
#             map_337a12422fceb13a7748c3bcf7478ba0.addLayer(marker_cluster_49b04ca0bca57d9a6e131596b8379b87);
#
#
#             var circle_marker_5c7ec980e60e7abf878ebead7d925809 = L.circleMarker(
#                 [48.0, -102.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_49b04ca0bca57d9a6e131596b8379b87);
#
#
#         var popup_fd6112ba3052edce8d90fd440d6ba9ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e688e4c159ce1d421e6cd7592e8a1f45 = $(`&lt;div id=&quot;html_e688e4c159ce1d421e6cd7592e8a1f45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;State : AL&lt;br&gt;                 %of Unemployment: 7.1&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_fd6112ba3052edce8d90fd440d6ba9ed.setContent(html_e688e4c159ce1d421e6cd7592e8a1f45);
#
#
#         circle_marker_5c7ec980e60e7abf878ebead7d925809.bindPopup(popup_fd6112ba3052edce8d90fd440d6ba9ed)
#         ;
#
#
#
#
#             var circle_marker_8895280b13f7f2e42c48b9e826de7c94 = L.circleMarker(
#                 [48.0, -102.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_49b04ca0bca57d9a6e131596b8379b87);
#
#
#         var popup_cf507a3c51eef9edaa50b1debb374366 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eeb0876c3ebb61b7044cda4eca08af00 = $(`&lt;div id=&quot;html_eeb0876c3ebb61b7044cda4eca08af00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;State : AK&lt;br&gt;                 %of Unemployment: 6.8&lt;br&gt;&lt;/div&gt;`)[0];
#             popup_cf507a3c51eef9edaa50b1debb374366.setContent(html_eeb0876c3ebb61b7044cda4eca08af00);
#
#
#         circle_marker_8895280b13f7f2e42c48b9e826de7c94.bindPopup(popup_cf507a3c51eef9edaa50b1debb374366)
#         ;
#
#
#
#
#             var circle_marker_605789158b0620cfd816c8425a4ef318 = L.circleMarker(
#                 [48.0, -102.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_49b04ca0bca57d9a6e131596b8379b87);
#
#
#         var popup_3dfe183b3dcb3a524745c6cf020600c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e0248d

# %% [markdown]
# 3. Tạo choropleth map theo ‘LUnemployment Rate (%)’ của từng bang theo gợi ý như hình sau:
